# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("Resources/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df= application_df.drop(['EIN', 'NAME'], axis=1)

# %%
# Look at APPLICATION_TYPE value counts for binning
application_type_counts = application_df['APPLICATION_TYPE'].value_counts()

# Determine which values to replace if counts are less than 500?
replace_application = list(application_type_counts[application_type_counts < 500].index)

# Replace in dataframe
for app in replace_application:
    application_df.APPLICATION_TYPE = application_df.APPLICATION_TYPE.replace(app,"Other")

# Look at CLASSIFICATION value counts for binning
classification_value_counts= application_df['CLASSIFICATION'].value_counts()

# Determine which values to replace if counts are less than ..?
replace_class = list(classification_value_counts[classification_value_counts < 500].index)

# Replace in dataframe
for cls in replace_class:
    application_df.CLASSIFICATION = application_df.CLASSIFICATION.replace(cls,"Other")
    
# Generate our categorical variable lists
application_cat = application_df.dtypes[application_df.dtypes == "object"].index.tolist()

# Create a OneHotEncoder instance
enc = OneHotEncoder(sparse=False)

# Fit and transform the OneHotEncoder using the categorical variable list
encode_df = pd.DataFrame(enc.fit_transform(application_df[application_cat]))

# Add the encoded variable names to the dataframe
encode_df.columns = enc.get_feature_names(application_cat)

# Merge one-hot encoded features and drop the originals
application_df = application_df.merge(encode_df, left_index=True,right_index=True)
application_df = application_df.drop(columns = application_cat)

# Split our preprocessed data into our features and target arrays
y = application_df['IS_SUCCESSFUL'].values
X = application_df.drop(['IS_SUCCESSFUL'],1).values
# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
# Out:
# /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:39: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only

# %% [markdown]
# ## Compile, train and evaluate the model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE

number_input_features = len(X_train[0])
hidden_nodes_layer1 = 80
hidden_nodes_layer2 = 30

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                3600
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 6,061
# Trainable params: 6,061
# Non-trainable params: 0
# _________________________________________________________________
# 2022-07-20 23:37:20.955146: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Import checkpoint dependencies
import os
from tensorflow.keras.callbacks import ModelCheckpoint

# Define the checkpoint path and filenames
os.makedirs("checkpoints/",exist_ok=True)
checkpoint_path = "checkpoints/weights.{epoch:02d}.hdf5"

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
# Create a callback that saves the model's weights every 5 epochs
cp_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    verbose=1,
    save_weights_only=True,
    save_freq='epoch',
    period=5)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=150, callbacks=[cp_callback])
# Out:
# Epoch 1/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5729 - accuracy: 0.7199
# Epoch 2/150
# 804/804 [==============================] - 1s 907us/step - loss: 0.5554 - accuracy: 0.7303
# Epoch 3/150
# 804/804 [==============================] - 1s 937us/step - loss: 0.5528 - accuracy: 0.7308
# Epoch 4/150
# 804/804 [==============================] - 1s 890us/step - loss: 0.5511 - accuracy: 0.7314
# Epoch 5/150
# 798/804 [============================>.] - ETA: 0s - loss: 0.5489 - accuracy: 0.7334
# Epoch 5: saving model to checkpoints/weights.05.hdf5
# 804/804 [==============================] - 1s 896us/step - loss: 0.5491 - accuracy: 0.7334
# Epoch 6/150
# 804/804 [==============================] - 1s 907us/step - loss: 0.5484 - accuracy: 0.7317
# Epoch 7/150
# 804/804 [==============================] - 1s 907us/step - loss: 0.5470 - accuracy: 0.7346
# Epoch 8/150
# 804/804 [==============================] - 1s 895us/step - loss: 0.5466 - accuracy: 0.7332
# Epoch 9/150
# 804/804 [==============================] - 1s 923us/step - loss: 0.5462 - accuracy: 0.7338
# Epoch 10/150
# 762/804 [===========================>..] - ETA: 0s - loss: 0.5455 - accuracy: 0.7333
# Epoch 10: saving model to checkpoints/weights.10.hdf5
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5448 - accuracy: 0.7345
# Epoch 11/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5450 - accuracy: 0.7348
# Epoch 12/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5446 - accuracy: 0.7359
# Epoch 13/150
# 804/804 [==============================] - 1s 997us/step - loss: 0.5438 - accuracy: 0.7364
# Epoch 14/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5435 - accuracy: 0.7357
# Epoch 15/150
# 782/804 [============================>.] - ETA: 0s - loss: 0.5437 - accuracy: 0.7359
# Epoch 15: saving model to checkpoints/weights.15.hdf5
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5435 - accuracy: 0.7360
# Epoch 16/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5433 - accuracy: 0.7370
# Epoch 17/150
# 804/804 [==============================] - 1s 978us/step - loss: 0.5425 - accuracy: 0.7359
# Epoch 18/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5421 - accuracy: 0.7372
# Epoch 19/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5418 - accuracy: 0.7376
# Epoch 20/150
# 760/804 [===========================>..] - ETA: 0s - loss: 0.5416 - accuracy: 0.7366
# Epoch 20: saving model to checkpoints/weights.20.hdf5
# 804/804 [==============================] - 1s 888us/step - loss: 0.5415 - accuracy: 0.7366
# Epoch 21/150
# 804/804 [==============================] - 1s 923us/step - loss: 0.5419 - accuracy: 0.7366
# Epoch 22/150
# 804/804 [==============================] - 1s 863us/step - loss: 0.5411 - accuracy: 0.7381
# Epoch 23/150
# 804/804 [==============================] - 1s 933us/step - loss: 0.5410 - accuracy: 0.7372
# Epoch 24/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5409 - accuracy: 0.7374
# Epoch 25/150
# 776/804 [===========================>..] - ETA: 0s - loss: 0.5404 - accuracy: 0.7382
# Epoch 25: saving model to checkpoints/weights.25.hdf5
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5407 - accuracy: 0.7381
# Epoch 26/150
# 804/804 [==============================] - 1s 911us/step - loss: 0.5403 - accuracy: 0.7382
# Epoch 27/150
# 804/804 [==============================] - 1s 961us/step - loss: 0.5398 - accuracy: 0.7382
# Epoch 28/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5402 - accuracy: 0.7378
# Epoch 29/150
# 804/804 [==============================] - 1s 994us/step - loss: 0.5398 - accuracy: 0.7382
# Epoch 30/150
# 797/804 [============================>.] - ETA: 0s - loss: 0.5392 - accuracy: 0.7387
# Epoch 30: saving model to checkpoints/weights.30.hdf5
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5392 - accuracy: 0.7385
# Epoch 31/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5393 - accuracy: 0.7377
# Epoch 32/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5394 - accuracy: 0.7380
# Epoch 33/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5384 - accuracy: 0.7386
# Epoch 34/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5393 - accuracy: 0.7392
# Epoch 35/150
# 756/804 [===========================>..] - ETA: 0s - loss: 0.5386 - accuracy: 0.7383
# Epoch 35: saving model to checkpoints/weights.35.hdf5
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5386 - accuracy: 0.7385
# Epoch 36/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5384 - accuracy: 0.7388
# Epoch 37/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5388 - accuracy: 0.7384
# Epoch 38/150
# 804/804 [==============================] - 1s 998us/step - loss: 0.5386 - accuracy: 0.7383
# Epoch 39/150
# 804/804 [==============================] - 1s 903us/step - loss: 0.5386 - accuracy: 0.7393
# Epoch 40/150
# 795/804 [============================>.] - ETA: 0s - loss: 0.5379 - accuracy: 0.7398
# Epoch 40: saving model to checkpoints/weights.40.hdf5
# 804/804 [==============================] - 1s 900us/step - loss: 0.5382 - accuracy: 0.7394
# Epoch 41/150
# 804/804 [==============================] - 1s 913us/step - loss: 0.5380 - accuracy: 0.7385
# Epoch 42/150
# 804/804 [==============================] - 1s 904us/step - loss: 0.5381 - accuracy: 0.7396
# Epoch 43/150
# 804/804 [==============================] - 1s 902us/step - loss: 0.5376 - accuracy: 0.7392
# Epoch 44/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5381 - accuracy: 0.7396
# Epoch 45/150
# 795/804 [============================>.] - ETA: 0s - loss: 0.5379 - accuracy: 0.7385
# Epoch 45: saving model to checkpoints/weights.45.hdf5
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5378 - accuracy: 0.7385
# Epoch 46/150
# 804/804 [==============================] - 1s 906us/step - loss: 0.5380 - accuracy: 0.7386
# Epoch 47/150
# 804/804 [==============================] - 1s 919us/step - loss: 0.5375 - accuracy: 0.7392
# Epoch 48/150
# 804/804 [==============================] - 1s 924us/step - loss: 0.5370 - accuracy: 0.7397
# Epoch 49/150
# 804/804 [==============================] - 1s 951us/step - loss: 0.5375 - accuracy: 0.7395
# Epoch 50/150
# 774/804 [===========================>..] - ETA: 0s - loss: 0.5376 - accuracy: 0.7397
# Epoch 50: saving model to checkpoints/weights.50.hdf5
# 804/804 [==============================] - 1s 923us/step - loss: 0.5375 - accuracy: 0.7396
# Epoch 51/150
# 804/804 [==============================] - 1s 920us/step - loss: 0.5372 - accuracy: 0.7384
# Epoch 52/150
# 804/804 [==============================] - 1s 938us/step - loss: 0.5369 - accuracy: 0.7400
# Epoch 53/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5371 - accuracy: 0.7396
# Epoch 54/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5366 - accuracy: 0.7406
# Epoch 55/150
# 802/804 [============================>.] - ETA: 0s - loss: 0.5369 - accuracy: 0.7394
# Epoch 55: saving model to checkpoints/weights.55.hdf5
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5367 - accuracy: 0.7395
# Epoch 56/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5373 - accuracy: 0.7393
# Epoch 57/150
# 804/804 [==============================] - 1s 974us/step - loss: 0.5364 - accuracy: 0.7403
# Epoch 58/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5368 - accuracy: 0.7397
# Epoch 59/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5366 - accuracy: 0.7392
# Epoch 60/150
# 796/804 [============================>.] - ETA: 0s - loss: 0.5362 - accuracy: 0.7403
# Epoch 60: saving model to checkpoints/weights.60.hdf5
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5363 - accuracy: 0.7403
# Epoch 61/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5363 - accuracy: 0.7404
# Epoch 62/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5363 - accuracy: 0.7404
# Epoch 63/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5361 - accuracy: 0.7405
# Epoch 64/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5362 - accuracy: 0.7404
# Epoch 65/150
# 774/804 [===========================>..] - ETA: 0s - loss: 0.5367 - accuracy: 0.7389
# Epoch 65: saving model to checkpoints/weights.65.hdf5
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5359 - accuracy: 0.7395
# Epoch 66/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5366 - accuracy: 0.7408
# Epoch 67/150
# 804/804 [==============================] - 1s 953us/step - loss: 0.5360 - accuracy: 0.7406
# Epoch 68/150
# 804/804 [==============================] - 1s 940us/step - loss: 0.5354 - accuracy: 0.7409
# Epoch 69/150
# 804/804 [==============================] - 1s 910us/step - loss: 0.5356 - accuracy: 0.7406
# Epoch 70/150
# 781/804 [============================>.] - ETA: 0s - loss: 0.5367 - accuracy: 0.7398
# Epoch 70: saving model to checkpoints/weights.70.hdf5
# 804/804 [==============================] - 1s 914us/step - loss: 0.5363 - accuracy: 0.7400
# Epoch 71/150
# 804/804 [==============================] - 1s 932us/step - loss: 0.5356 - accuracy: 0.7402
# Epoch 72/150
# 804/804 [==============================] - 1s 902us/step - loss: 0.5353 - accuracy: 0.7402
# Epoch 73/150
# 804/804 [==============================] - 1s 900us/step - loss: 0.5356 - accuracy: 0.7406
# Epoch 74/150
# 804/804 [==============================] - 1s 905us/step - loss: 0.5351 - accuracy: 0.7404
# Epoch 75/150
# 776/804 [===========================>..] - ETA: 0s - loss: 0.5360 - accuracy: 0.7397
# Epoch 75: saving model to checkpoints/weights.75.hdf5
# 804/804 [==============================] - 1s 922us/step - loss: 0.5359 - accuracy: 0.7404
# Epoch 76/150
# 804/804 [==============================] - 1s 903us/step - loss: 0.5353 - accuracy: 0.7398
# Epoch 77/150
# 804/804 [==============================] - 1s 898us/step - loss: 0.5352 - accuracy: 0.7407
# Epoch 78/150
# 804/804 [==============================] - 1s 941us/step - loss: 0.5350 - accuracy: 0.7405
# Epoch 79/150
# 804/804 [==============================] - 1s 940us/step - loss: 0.5352 - accuracy: 0.7407
# Epoch 80/150
# 790/804 [============================>.] - ETA: 0s - loss: 0.5340 - accuracy: 0.7406
# Epoch 80: saving model to checkpoints/weights.80.hdf5
# 804/804 [==============================] - 1s 970us/step - loss: 0.5344 - accuracy: 0.7404
# Epoch 81/150
# 804/804 [==============================] - 1s 942us/step - loss: 0.5353 - accuracy: 0.7408
# Epoch 82/150
# 804/804 [==============================] - 1s 944us/step - loss: 0.5348 - accuracy: 0.7411
# Epoch 83/150
# 804/804 [==============================] - 1s 938us/step - loss: 0.5351 - accuracy: 0.7407
# Epoch 84/150
# 804/804 [==============================] - 1s 947us/step - loss: 0.5350 - accuracy: 0.7409
# Epoch 85/150
# 804/804 [==============================] - ETA: 0s - loss: 0.5349 - accuracy: 0.7411
# Epoch 85: saving model to checkpoints/weights.85.hdf5
# 804/804 [==============================] - 1s 952us/step - loss: 0.5349 - accuracy: 0.7411
# Epoch 86/150
# 804/804 [==============================] - 1s 945us/step - loss: 0.5347 - accuracy: 0.7412
# Epoch 87/150
# 804/804 [==============================] - 1s 936us/step - loss: 0.5347 - accuracy: 0.7406
# Epoch 88/150
# 804/804 [==============================] - 1s 941us/step - loss: 0.5343 - accuracy: 0.7412
# Epoch 89/150
# 804/804 [==============================] - 1s 941us/step - loss: 0.5350 - accuracy: 0.7416
# Epoch 90/150
# 800/804 [============================>.] - ETA: 0s - loss: 0.5349 - accuracy: 0.7405
# Epoch 90: saving model to checkpoints/weights.90.hdf5
# 804/804 [==============================] - 1s 963us/step - loss: 0.5349 - accuracy: 0.7404
# Epoch 91/150
# 804/804 [==============================] - 1s 969us/step - loss: 0.5342 - accuracy: 0.7412
# Epoch 92/150
# 804/804 [==============================] - 1s 939us/step - loss: 0.5348 - accuracy: 0.7409
# Epoch 93/150
# 804/804 [==============================] - 1s 939us/step - loss: 0.5342 - accuracy: 0.7406
# Epoch 94/150
# 804/804 [==============================] - 1s 943us/step - loss: 0.5345 - accuracy: 0.7408
# Epoch 95/150
# 788/804 [============================>.] - ETA: 0s - loss: 0.5344 - accuracy: 0.7414
# Epoch 95: saving model to checkpoints/weights.95.hdf5
# 804/804 [==============================] - 1s 975us/step - loss: 0.5347 - accuracy: 0.7414
# Epoch 96/150
# 804/804 [==============================] - 1s 943us/step - loss: 0.5342 - accuracy: 0.7416
# Epoch 97/150
# 804/804 [==============================] - 1s 941us/step - loss: 0.5343 - accuracy: 0.7407
# Epoch 98/150
# 804/804 [==============================] - 1s 942us/step - loss: 0.5345 - accuracy: 0.7409
# Epoch 99/150
# 804/804 [==============================] - 1s 945us/step - loss: 0.5343 - accuracy: 0.7409
# Epoch 100/150
# 768/804 [===========================>..] - ETA: 0s - loss: 0.5340 - accuracy: 0.7403
# Epoch 100: saving model to checkpoints/weights.100.hdf5
# 804/804 [==============================] - 1s 996us/step - loss: 0.5340 - accuracy: 0.7407
# Epoch 101/150
# 804/804 [==============================] - 1s 945us/step - loss: 0.5348 - accuracy: 0.7410
# Epoch 102/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5337 - accuracy: 0.7409
# Epoch 103/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5342 - accuracy: 0.7402
# Epoch 104/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5339 - accuracy: 0.7418
# Epoch 105/150
# 769/804 [===========================>..] - ETA: 0s - loss: 0.5340 - accuracy: 0.7417
# Epoch 105: saving model to checkpoints/weights.105.hdf5
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5342 - accuracy: 0.7415
# Epoch 106/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5342 - accuracy: 0.7414
# Epoch 107/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5336 - accuracy: 0.7419
# Epoch 108/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5342 - accuracy: 0.7411
# Epoch 109/150
# 804/804 [==============================] - 1s 984us/step - loss: 0.5336 - accuracy: 0.7413
# Epoch 110/150
# 795/804 [============================>.] - ETA: 0s - loss: 0.5333 - accuracy: 0.7417
# Epoch 110: saving model to checkpoints/weights.110.hdf5
# 804/804 [==============================] - 1s 964us/step - loss: 0.5336 - accuracy: 0.7416
# Epoch 111/150
# 804/804 [==============================] - 1s 971us/step - loss: 0.5340 - accuracy: 0.7406
# Epoch 112/150
# 804/804 [==============================] - 1s 955us/step - loss: 0.5340 - accuracy: 0.7409
# Epoch 113/150
# 804/804 [==============================] - 1s 926us/step - loss: 0.5337 - accuracy: 0.7415
# Epoch 114/150
# 804/804 [==============================] - 1s 914us/step - loss: 0.5337 - accuracy: 0.7417
# Epoch 115/150
# 770/804 [===========================>..] - ETA: 0s - loss: 0.5330 - accuracy: 0.7413
# Epoch 115: saving model to checkpoints/weights.115.hdf5
# 804/804 [==============================] - 1s 927us/step - loss: 0.5335 - accuracy: 0.7411
# Epoch 116/150
# 804/804 [==============================] - 1s 904us/step - loss: 0.5332 - accuracy: 0.7417
# Epoch 117/150
# 804/804 [==============================] - 1s 907us/step - loss: 0.5336 - accuracy: 0.7412
# Epoch 118/150
# 804/804 [==============================] - 1s 903us/step - loss: 0.5338 - accuracy: 0.7414
# Epoch 119/150
# 804/804 [==============================] - 1s 902us/step - loss: 0.5335 - accuracy: 0.7419
# Epoch 120/150
# 781/804 [============================>.] - ETA: 0s - loss: 0.5339 - accuracy: 0.7399
# Epoch 120: saving model to checkpoints/weights.120.hdf5
# 804/804 [==============================] - 1s 917us/step - loss: 0.5334 - accuracy: 0.7406
# Epoch 121/150
# 804/804 [==============================] - 1s 925us/step - loss: 0.5335 - accuracy: 0.7413
# Epoch 122/150
# 804/804 [==============================] - 1s 907us/step - loss: 0.5334 - accuracy: 0.7410
# Epoch 123/150
# 804/804 [==============================] - 1s 902us/step - loss: 0.5331 - accuracy: 0.7418
# Epoch 124/150
# 804/804 [==============================] - 1s 907us/step - loss: 0.5334 - accuracy: 0.7419
# Epoch 125/150
# 787/804 [============================>.] - ETA: 0s - loss: 0.5332 - accuracy: 0.7418
# Epoch 125: saving model to checkpoints/weights.125.hdf5
# 804/804 [==============================] - 1s 912us/step - loss: 0.5332 - accuracy: 0.7419
# Epoch 126/150
# 804/804 [==============================] - 1s 902us/step - loss: 0.5337 - accuracy: 0.7411
# Epoch 127/150
# 804/804 [==============================] - 1s 902us/step - loss: 0.5330 - accuracy: 0.7412
# Epoch 128/150
# 804/804 [==============================] - 1s 893us/step - loss: 0.5335 - accuracy: 0.7416
# Epoch 129/150
# 804/804 [==============================] - 1s 905us/step - loss: 0.5332 - accuracy: 0.7412
# Epoch 130/150
# 793/804 [============================>.] - ETA: 0s - loss: 0.5324 - accuracy: 0.7409
# Epoch 130: saving model to checkpoints/weights.130.hdf5
# 804/804 [==============================] - 1s 902us/step - loss: 0.5328 - accuracy: 0.7405
# Epoch 131/150
# 804/804 [==============================] - 1s 893us/step - loss: 0.5327 - accuracy: 0.7419
# Epoch 132/150
# 804/804 [==============================] - 1s 912us/step - loss: 0.5334 - accuracy: 0.7413
# Epoch 133/150
# 804/804 [==============================] - 1s 890us/step - loss: 0.5328 - accuracy: 0.7413
# Epoch 134/150
# 804/804 [==============================] - 1s 898us/step - loss: 0.5331 - accuracy: 0.7411
# Epoch 135/150
# 796/804 [============================>.] - ETA: 0s - loss: 0.5342 - accuracy: 0.7406
# Epoch 135: saving model to checkpoints/weights.135.hdf5
# 804/804 [==============================] - 1s 901us/step - loss: 0.5340 - accuracy: 0.7409
# Epoch 136/150
# 804/804 [==============================] - 1s 902us/step - loss: 0.5327 - accuracy: 0.7415
# Epoch 137/150
# 804/804 [==============================] - 1s 895us/step - loss: 0.5329 - accuracy: 0.7419
# Epoch 138/150
# 804/804 [==============================] - 1s 898us/step - loss: 0.5327 - accuracy: 0.7418
# Epoch 139/150
# 804/804 [==============================] - 1s 893us/step - loss: 0.5331 - accuracy: 0.7415
# Epoch 140/150
# 780/804 [============================>.] - ETA: 0s - loss: 0.5328 - accuracy: 0.7411
# Epoch 140: saving model to checkpoints/weights.140.hdf5
# 804/804 [==============================] - 1s 917us/step - loss: 0.5325 - accuracy: 0.7414
# Epoch 141/150
# 804/804 [==============================] - 1s 939us/step - loss: 0.5326 - accuracy: 0.7418
# Epoch 142/150
# 804/804 [==============================] - 1s 910us/step - loss: 0.5326 - accuracy: 0.7423
# Epoch 143/150
# 804/804 [==============================] - 1s 924us/step - loss: 0.5331 - accuracy: 0.7415
# Epoch 144/150
# 804/804 [==============================] - 1s 912us/step - loss: 0.5328 - accuracy: 0.7418
# Epoch 145/150
# 783/804 [============================>.] - ETA: 0s - loss: 0.5336 - accuracy: 0.7417
# Epoch 145: saving model to checkpoints/weights.145.hdf5
# 804/804 [==============================] - 1s 916us/step - loss: 0.5328 - accuracy: 0.7423
# Epoch 146/150
# 804/804 [==============================] - 1s 926us/step - loss: 0.5335 - accuracy: 0.7418
# Epoch 147/150
# 804/804 [==============================] - 1s 911us/step - loss: 0.5330 - accuracy: 0.7416
# Epoch 148/150
# 804/804 [==============================] - 1s 909us/step - loss: 0.5325 - accuracy: 0.7421
# Epoch 149/150
# 804/804 [==============================] - 1s 922us/step - loss: 0.5324 - accuracy: 0.7407
# Epoch 150/150
# 780/804 [============================>.] - ETA: 0s - loss: 0.5319 - accuracy: 0.7425
# Epoch 150: saving model to checkpoints/weights.150.hdf5
# 804/804 [==============================] - 1s 918us/step - loss: 0.5323 - accuracy: 0.7423

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5605 - accuracy: 0.7255 - 288ms/epoch - 1ms/step
# Loss: 0.5604745745658875, Accuracy: 0.7254810333251953

# %%
# Export and save model to HDF5 file
nn.save("AlphabetSoupCharity_Optimization2.h5")
